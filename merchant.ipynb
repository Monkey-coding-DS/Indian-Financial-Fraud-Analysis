# %% [markdown]
# # 🏪 Мерчанты
#
# **Набор данных о мерчантах (торговых точках)** — часть исследовательского проекта по анализу индийских финансовых данных и выявлению мошеннических операций.
#
# Цель данного ноутбука — провести **разведочный анализ данных (EDA)** набора `merchant_table.csv`: изучить структуру данных, распределения признаков и связи между ними.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv("data/merchant_table.csv")

print(f"Количество строк {df.shape[0]}, количество столбцов {df.shape[1]}")
print("\n-----------------------")
print("Информация о типах данных")
print(df.info())
print("\n-----------------------")
print("Выборка первых записей")
print(df.head())
print("\n-----------------------")
print("Количество дубликатов")
print(df.duplicated().sum())
print("\n-----------------------")
print("Количество пропущенных значений")
print(df.isna().sum())
print("\n-----------------------")
print("распределение числовых данных")
print(df.describe())
# Out:
# Количество строк 500, количество столбцов 9
#
# -----------------------
# Информация о типах данных
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Merchant_ID          500 non-null    str
#  1   Merchant_Name        500 non-null    str
#  2   Merchant_Category    500 non-null    str
#  3   State                500 non-null    str
#  4   City                 500 non-null    str
#  5   Merchant_Risk_Level  500 non-null    str
#  6   Merchant_Rating      500 non-null    float64
#  7   Merchant_Status      500 non-null    str
#  8   Merchant_Since       500 non-null    str
# dtypes: float64(1), str(8)
# memory usage: 35.3 KB
# None
#
# -----------------------
# Выборка первых записей
#   Merchant_ID    Merchant_Name Merchant_Category       State         City  \
# ...
